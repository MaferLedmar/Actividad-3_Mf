# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('inmuebles_sin_nulos.csv') 
data
# Out:
#       Unnamed: 0   0.1           Fecha Alta        Tipo Operación  Provincia  \
# 0              0     1  2004-01-01 00:00:00     Parking  Alquiler     Lleida
# 1              1     2  2004-01-01 00:00:00       Local     Venta     Girona
# 2              2     3  2004-01-01 00:00:00     Oficina  Alquiler     Girona
# 3              3     4  2004-01-02 00:00:00     Parking  Alquiler     Girona
# 4              4     5  2004-01-02 00:00:00       Suelo     Venta  Tarragona
# ...          ...   ...                  ...         ...       ...        ...
# 3332        3332  3333  2007-04-29 00:00:00  Industrial  Alquiler     Lleida
# 3333        3333  3334  2007-04-29 00:00:00        Piso  Alquiler     Girona
# 3334        3334  3335  2007-04-30 00:00:00       Suelo     Venta  Tarragona
# 3335        3335  3336  2007-04-30 00:00:00        Piso  Alquiler  Barcelona
# 3336        3336  3337  2007-04-30 00:00:00     Parking     Venta     Lleida
#
#       Superficie  Precio Venta          Fecha Venta Vendedor
# 0          291.0    12133903.0  2004-06-19 00:00:00   Carmen
# 1          185.0     1945424.0  2004-04-19 00:00:00    Pedro
# 2           82.0     1121906.0  2004-11-08 00:00:00  Joaquín
# 3          285.0     1121906.0  2004-04-27 00:00:00    Jesús
# 4          152.0      185000.0  2004-07-10 00:00:00    María
# ...          ...           ...                  ...      ...
# 3332       221.0     1450644.0  2030-06-19 00:00:00    María
# 3333        55.0      454080.0  2030-06-19 00:00:00    María
# 3334        78.0      740688.0  2030-06-19 00:00:00    María
# 3335        88.0      397408.0  2030-06-19 00:00:00    María
# 3336       170.2     2140712.0  2030-06-19 00:00:00    María
#
# [3337 rows x 10 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0      0
# 0.1             0
# Fecha Alta      0
# Tipo            0
# Operación       0
# Provincia       0
# Superficie      0
# Precio Venta    0
# Fecha Venta     0
# Vendedor        0
# dtype: int64

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=data["Precio Venta"], color='blue', rwidth=0.50)
plt.title('Histograma de Precio de ventas')
plt.xlabel('Precio Venta')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data["Precio Venta"]) 
plt.title("Outliers de Precio Venta")
plt.show() #dibujamos el diagrama

# %% [markdown]
# *****************************MÉTODO DE DESVIACIÓN ESTÁNDAR*********************************

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data["Precio Venta"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 3567004.535714437
# Limite inferior permitido -1133684.336133975

# %%
#Encontramos Ouliers
outliers= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#      Unnamed: 0  0.1           Fecha Alta     Tipo Operación  Provincia  \
# 0             0    1  2004-01-01 00:00:00  Parking  Alquiler     Lleida
# 89           89   90  2004-02-04 00:00:00    Suelo     Venta     Girona
# 141         141  142  2004-02-27 00:00:00  Oficina     Venta  Tarragona
# 182         182  183  2004-03-14 00:00:00    Local  Alquiler     Girona
#
#      Superficie  Precio Venta          Fecha Venta Vendedor
# 0         291.0    12133903.0  2004-06-19 00:00:00   Carmen
# 89        292.0    12685816.0  2004-07-24 00:00:00    Pedro
# 141       123.0    11128156.0  2004-09-23 00:00:00    Pedro
# 182       231.0    21446522.0  2004-09-02 00:00:00   Carmen

# %%
#Obtenemos datos limpios
data_clean= data[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean
# Out:
#       Unnamed: 0   0.1           Fecha Alta        Tipo Operación  Provincia  \
# 1              1     2  2004-01-01 00:00:00       Local     Venta     Girona
# 2              2     3  2004-01-01 00:00:00     Oficina  Alquiler     Girona
# 3              3     4  2004-01-02 00:00:00     Parking  Alquiler     Girona
# 4              4     5  2004-01-02 00:00:00       Suelo     Venta  Tarragona
# 5              5     6  2004-01-03 00:00:00  Industrial  Alquiler     Girona
# ...          ...   ...                  ...         ...       ...        ...
# 3332        3332  3333  2007-04-29 00:00:00  Industrial  Alquiler     Lleida
# 3333        3333  3334  2007-04-29 00:00:00        Piso  Alquiler     Girona
# 3334        3334  3335  2007-04-30 00:00:00       Suelo     Venta  Tarragona
# 3335        3335  3336  2007-04-30 00:00:00        Piso  Alquiler  Barcelona
# 3336        3336  3337  2007-04-30 00:00:00     Parking     Venta     Lleida
#
#       Superficie  Precio Venta          Fecha Venta Vendedor
# 1          185.0     1945424.0  2004-04-19 00:00:00    Pedro
# 2           82.0     1121906.0  2004-11-08 00:00:00  Joaquín
# 3          285.0     1121906.0  2004-04-27 00:00:00    Jesús
# 4          152.0      185000.0  2004-07-10 00:00:00    María
# 5          131.0      953156.0  2004-09-05 00:00:00    Pedro
# ...          ...           ...                  ...      ...
# 3332       221.0     1450644.0  2030-06-19 00:00:00    María
# 3333        55.0      454080.0  2030-06-19 00:00:00    María
# 3334        78.0      740688.0  2030-06-19 00:00:00    María
# 3335        88.0      397408.0  2030-06-19 00:00:00    María
# 3336       170.2     2140712.0  2030-06-19 00:00:00    María
#
# [3333 rows x 10 columns]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["Precio Venta"]) 
plt.title("Outliers de Precio Venta")
plt.show() #dibujamos el diagrama

# %% [markdown]
# *****************************MÉTODO DE IQR (RANGO INTER QUARTILICO)*********************************

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data["Precio Venta"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 3012316.5
# Limite inferior permitido -694127.5

# %%
#Encontramos Ouliers
outliers_iqr= data[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#      Unnamed: 0  0.1           Fecha Alta     Tipo Operación  Provincia  \
# 0             0    1  2004-01-01 00:00:00  Parking  Alquiler     Lleida
# 89           89   90  2004-02-04 00:00:00    Suelo     Venta     Girona
# 141         141  142  2004-02-27 00:00:00  Oficina     Venta  Tarragona
# 182         182  183  2004-03-14 00:00:00    Local  Alquiler     Girona
#
#      Superficie  Precio Venta          Fecha Venta Vendedor
# 0         291.0    12133903.0  2004-06-19 00:00:00   Carmen
# 89        292.0    12685816.0  2004-07-24 00:00:00    Pedro
# 141       123.0    11128156.0  2004-09-23 00:00:00    Pedro
# 182       231.0    21446522.0  2004-09-02 00:00:00   Carmen

# %%
#Obtenemos datos limpios
data_clean_iqr= data[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#       Unnamed: 0   0.1           Fecha Alta        Tipo Operación  Provincia  \
# 1              1     2  2004-01-01 00:00:00       Local     Venta     Girona
# 2              2     3  2004-01-01 00:00:00     Oficina  Alquiler     Girona
# 3              3     4  2004-01-02 00:00:00     Parking  Alquiler     Girona
# 4              4     5  2004-01-02 00:00:00       Suelo     Venta  Tarragona
# 5              5     6  2004-01-03 00:00:00  Industrial  Alquiler     Girona
# ...          ...   ...                  ...         ...       ...        ...
# 3332        3332  3333  2007-04-29 00:00:00  Industrial  Alquiler     Lleida
# 3333        3333  3334  2007-04-29 00:00:00        Piso  Alquiler     Girona
# 3334        3334  3335  2007-04-30 00:00:00       Suelo     Venta  Tarragona
# 3335        3335  3336  2007-04-30 00:00:00        Piso  Alquiler  Barcelona
# 3336        3336  3337  2007-04-30 00:00:00     Parking     Venta     Lleida
#
#       Superficie  Precio Venta          Fecha Venta Vendedor
# 1          185.0     1945424.0  2004-04-19 00:00:00    Pedro
# 2           82.0     1121906.0  2004-11-08 00:00:00  Joaquín
# 3          285.0     1121906.0  2004-04-27 00:00:00    Jesús
# 4          152.0      185000.0  2004-07-10 00:00:00    María
# 5          131.0      953156.0  2004-09-05 00:00:00    Pedro
# ...          ...           ...                  ...      ...
# 3332       221.0     1450644.0  2030-06-19 00:00:00    María
# 3333        55.0      454080.0  2030-06-19 00:00:00    María
# 3334        78.0      740688.0  2030-06-19 00:00:00    María
# 3335        88.0      397408.0  2030-06-19 00:00:00    María
# 3336       170.2     2140712.0  2030-06-19 00:00:00    María
#
# [3333 rows x 10 columns]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["Precio Venta"]) 
plt.title("Outliers de Precio Venta")
plt.show() #dibujamos el diagrama
